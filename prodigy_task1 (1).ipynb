# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

data = pd.read_csv("D:\My Data\Downloads\population data.csv")
data.head()
# Out:
#                   Country Name Country Code     Indicator Name Indicator Code  \
# 0                        Aruba          ABW  Population, total    SP.POP.TOTL
# 1  Africa Eastern and Southern          AFE  Population, total    SP.POP.TOTL
# 2                  Afghanistan          AFG  Population, total    SP.POP.TOTL
# 3   Africa Western and Central          AFW  Population, total    SP.POP.TOTL
# 4                       Angola          AGO  Population, total    SP.POP.TOTL
#
#           1960         1961         1962         1963         1964  \
# 0      54608.0      55811.0      56682.0      57475.0      58178.0
# 1  130692579.0  134169237.0  137835590.0  141630546.0  145605995.0
# 2    8622466.0    8790140.0    8969047.0    9157465.0    9355514.0
# 3   97256290.0   99314028.0  101445032.0  103667517.0  105959979.0
# 4    5357195.0    5441333.0    5521400.0    5599827.0    5673199.0
#
#           1965  ...         2013         2014         2015         2016  \
# ...

# %%
data.columns
# Out:
# Index(['Country Name', 'Country Code', 'Indicator Name', 'Indicator Code',
#        '1960', '1961', '1962', '1963', '1964', '1965', '1966', '1967', '1968',
#        '1969', '1970', '1971', '1972', '1973', '1974', '1975', '1976', '1977',
#        '1978', '1979', '1980', '1981', '1982', '1983', '1984', '1985', '1986',
#        '1987', '1988', '1989', '1990', '1991', '1992', '1993', '1994', '1995',
#        '1996', '1997', '1998', '1999', '2000', '2001', '2002', '2003', '2004',
#        '2005', '2006', '2007', '2008', '2009', '2010', '2011', '2012', '2013',
#        '2014', '2015', '2016', '2017', '2018', '2019', '2020', '2021', '2022'],
#       dtype='object')

# %%
data1=data.dropna()
data1.head()
# Out:
#                   Country Name Country Code     Indicator Name Indicator Code  \
# 0                        Aruba          ABW  Population, total    SP.POP.TOTL
# 1  Africa Eastern and Southern          AFE  Population, total    SP.POP.TOTL
# 2                  Afghanistan          AFG  Population, total    SP.POP.TOTL
# 3   Africa Western and Central          AFW  Population, total    SP.POP.TOTL
# 4                       Angola          AGO  Population, total    SP.POP.TOTL
#
#           1960         1961         1962         1963         1964  \
# 0      54608.0      55811.0      56682.0      57475.0      58178.0
# 1  130692579.0  134169237.0  137835590.0  141630546.0  145605995.0
# 2    8622466.0    8790140.0    8969047.0    9157465.0    9355514.0
# 3   97256290.0   99314028.0  101445032.0  103667517.0  105959979.0
# 4    5357195.0    5441333.0    5521400.0    5599827.0    5673199.0
#
#           1965  ...         2013         2014         2015         2016  \
# ...

# %%
data1.describe()
# Out:
#                1960          1961          1962          1963          1964  \
# count  2.640000e+02  2.640000e+02  2.640000e+02  2.640000e+02  2.640000e+02
# mean   1.172712e+08  1.188807e+08  1.210511e+08  1.237333e+08  1.264378e+08
# std    3.695439e+08  3.740897e+08  3.808061e+08  3.895039e+08  3.982439e+08
# min    2.646000e+03  2.888000e+03  3.171000e+03  3.481000e+03  3.811000e+03
# 25%    5.132212e+05  5.231345e+05  5.337595e+05  5.449288e+05  5.566630e+05
# 50%    3.757486e+06  3.887144e+06  4.023896e+06  4.139356e+06  4.224612e+06
# 75%    2.670606e+07  2.748694e+07  2.830289e+07  2.914708e+07  3.001684e+07
# max    3.031474e+09  3.072422e+09  3.126850e+09  3.193429e+09  3.260442e+09
#
#                1965          1966          1967          1968          1969  \
# count  2.640000e+02  2.640000e+02  2.640000e+02  2.640000e+02  2.640000e+02
# mean   1.291813e+08  1.320404e+08  1.348980e+08  1.378358e+08  1.408789e+08
# ...

# %%
data['Country Code'].unique()
# Out:
# array(['ABW', 'AFE', 'AFG', 'AFW', 'AGO', 'ALB', 'AND', 'ARB', 'ARE',
#        'ARG', 'ARM', 'ASM', 'ATG', 'AUS', 'AUT', 'AZE', 'BDI', 'BEL',
#        'BEN', 'BFA', 'BGD', 'BGR', 'BHR', 'BHS', 'BIH', 'BLR', 'BLZ',
#        'BMU', 'BOL', 'BRA', 'BRB', 'BRN', 'BTN', 'BWA', 'CAF', 'CAN',
#        'CEB', 'CHE', 'CHI', 'CHL', 'CHN', 'CIV', 'CMR', 'COD', 'COG',
#        'COL', 'COM', 'CPV', 'CRI', 'CSS', 'CUB', 'CUW', 'CYM', 'CYP',
#        'CZE', 'DEU', 'DJI', 'DMA', 'DNK', 'DOM', 'DZA', 'EAP', 'EAR',
#        'EAS', 'ECA', 'ECS', 'ECU', 'EGY', 'EMU', 'ERI', 'ESP', 'EST',
#        'ETH', 'EUU', 'FCS', 'FIN', 'FJI', 'FRA', 'FRO', 'FSM', 'GAB',
#        'GBR', 'GEO', 'GHA', 'GIB', 'GIN', 'GMB', 'GNB', 'GNQ', 'GRC',
#        'GRD', 'GRL', 'GTM', 'GUM', 'GUY', 'HIC', 'HKG', 'HND', 'HPC',
#        'HRV', 'HTI', 'HUN', 'IBD', 'IBT', 'IDA', 'IDB', 'IDN', 'IDX',
#        'IMN', 'IND', 'INX', 'IRL', 'IRN', 'IRQ', 'ISL', 'ISR', 'ITA',
# ...

# %%
def average(data):
    avg_values = {}
    years = data.loc[:,'1970':'2021']
    
    for year in years:
        avg_values[year] = data[year].mean()
    
    return avg_values

avg_population = average(data)
print(avg_population)
# Out:
# {'1970': 143969335.7348485, '1971': 147116310.62121212, '1972': 150211541.34469697, '1973': 153350081.99621212, '1974': 156475472.54166666, '1975': 159536810.65530303, '1976': 162568442.66666666, '1977': 165589382.09469697, '1978': 168665653.45454547, '1979': 171826245.59469697, '1980': 175014615.88257575, '1981': 178281882.8219697, '1982': 181701096.9318182, '1983': 185149410.6060606, '1984': 188588784.36363637, '1985': 192101241.89772728, '1986': 195717360.41287878, '1987': 199432958.0, '1988': 203177006.17424244, '1989': 206919900.96212122, '1990': 209932838.39245284, '1991': 213643286.13207546, '1992': 217298283.73207548, '1993': 220932225.64150944, '1994': 224537007.50566038, '1995': 228114848.9283019, '1996': 231693099.8716981, '1997': 235258939.8716981, '1998': 238800268.29056603, '1999': 242308316.0490566, '2000': 245797145.65283018, '2001': 249293299.90943396, '2002': 252799313.3735849, '2003': 256302246.9509434, '2004': 259811313.4716981, '2005': 263337315.8716981, '2006': 
# ...

# %%
# Plotting the bar chart
plt.figure(figsize=(10, 6))
plt.bar(avg_population.keys(), avg_population.values(), color='blue')
plt.xlabel('Year')
plt.ylabel('Population')
plt.title('Average Population')
plt.xticks(rotation=90)
plt.show()

# %%
countries = ['AFG', 'CHN', 'IND', 'PAK', 'MEX']  # Example countries

# Choose the indicator
indicator_name = 'Population, total'  # Population indicator

# Extract years and corresponding population values for the selected countries
years = range(1970, 2023)
country_data = data[data['Indicator Name'] == indicator_name]
country_data = country_data[country_data['Country Code'].isin(countries)]
country_data = country_data.set_index('Country Code')
country_data = country_data.loc[countries, '1970':]

# Plot the population trends for the selected countries
plt.figure(figsize=(10, 6))  #size of the graph
for country in countries:
    plt.plot(years, country_data.loc[country], label=country)

# Set labels and title
plt.xlabel('Year')
plt.ylabel(indicator_name)
plt.title(f'{indicator_name} Trends for Selected Countries')
plt.legend()
plt.grid(True)
plt.xticks(range(1970, 2023, 5))  # Show ticks every 5 years for better readability
plt.tight_layout()

plt.show()
